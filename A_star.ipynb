# %%
import time
import numpy as np
import pandas as pd
from random import randint
import copy

# %%
class Graph:
    def __init__(self, graph_dict):
        self.graph_dict = graph_dict
 
    def neighbors(self, v):
        return self.graph_dict[v]
 
    def h(self, n):
        return H(n)
    
 
    def a_star_algorithm(self, start, stop):
        count=0
        if start not in cities_lst or stop not in cities_lst:
            raise Exception('City name incorrect!')
        active_lst = set([start])
        finished_lst = set([])
 
        # cost  present distances from start to  other nodes
        cost = {}
        cost[start] = 0
        #par is to find parents of a node
        par = {}
        par[start] = start
 
        while len(active_lst) > 0:
            
            n = None
 
            # it will find a node with the lowest value of f() in active lst
            for v in active_lst:
                if n == None or cost[v] + self.h(v) < cost[n] + self.h(n):
                    n = v;
 
            if n == None:
                print('Path does not exist!')
                return None
            if n == stop:
                reconst_path = []
 
                while par[n] != n:
                    reconst_path.append(n)
                    n = par[n]
 
                reconst_path.append(start)
 
                reconst_path.reverse()
                s=0
                for i in range(len(reconst_path)-1):
                    for j in map[reconst_path[i]]:
                        if j[0]==reconst_path[i+1]:
                            s+=j[1]
                print('Total node expanded:', count)
                print('Total cost: ',s)            
                return reconst_path
             # for all the neighbors of the current node do
            for m, weight in self.neighbors(n):
                count+=1
                
                # if the current node is not presentin both active_lst and finished_lst
                # add it to active_lst and note n as it's par
                if m not in active_lst and m not in finished_lst:
                    active_lst.add(m)
                    par[m] = n
                    cost[m] = cost[n] + weight
                # otherwise, check if it's quicker to first visit n, then m
                # and if it is, update par data and cost data
                # and if the node was in the closed_lst, move it to open_lst
                else:
                    if cost[m] > cost[n] + weight:
                        cost[m] = cost[n] + weight
                        par[m] = n
                         
                        if m in finished_lst:
                            finished_lst.remove(m)
                            active_lst.add(m)
            
            # remove n from the active_lst, and add it to finished_lst 
            active_lst.remove(n)
            finished_lst.add(n)
        print('Path does not exist!')
        return None

# %%
# travelling cost between adjacent cities
df=pd.read_csv('/content/data/route-info1.csv')
data=df.to_numpy()
highway_data=data
# flight_fee=data1
fee=highway_data[:,2:3]*10+highway_data[:,3:4]
highway_fee=np.hstack((highway_data[:,:2],fee))
final_fee=highway_fee
print(final_fee[0:5])
# Out:
# [['Guwahati' 'Rangia' 345.0]
#  ['Guwahati' 'Mangaldai' 448.0]
#  ['Guwahati' 'Jagiroad' 481.0]
#  ['Rangia' 'Udalguri' 592.0]
#  ['Udalguri' 'Mazbat' 170.0]]

# %%
map=dict()
for i in final_fee:
    map[i[0]]=map.get(i[0],[])
    map[i[0]].append((i[1],i[2]))
    map[i[1]]=map.get(i[1],[])
    map[i[1]].append((i[0],i[2]))
cities_lst=map.keys()
print(list(cities_lst))
# Out:
# ['Guwahati', 'Rangia', 'Mangaldai', 'Jagiroad', 'Udalguri', 'Mazbat', 'Rangapara', 'Biswanath Charali', 'Gohpur', 'Bihpuria', 'North Lakhimpur', 'Gogamukh', 'Dhemaji', 'Silapathar', 'Dibrugarh', 'Hojai', 'Lamding', 'Diphu', 'Mariani', 'Simaluguri', 'Namrup', 'Naharkatiya', 'Duliajan', 'Bordubi', 'Tinsukia', 'Nagaon', 'Bokakhat', 'Dergaon', 'Jorhat', 'Sibsagar', 'Dimow', 'Moranhat']

# %%
# getting heuristics data
df2=pd.read_csv('/content/data/city-label1.csv', header=None)
da=df2.to_numpy()
da=da.reshape((2,-1))
label=dict()
da=list(da)
for i in range(len(da[0])):
    label[da[0][i]]=i
df1=pd.read_csv('/content/data/heuristics.csv', header=None)
data1=df1.to_numpy()

# %%
# find straight-line distance from start city to other cities
start='Guwahati'
destination='Dibrugarh'
def find_heuristic(start, destination):
    if destination not in cities_lst:
        raise Exception("this city is not included in the map")
    data3=[]
    index=label[destination]
    for i in label:
        data3.append([i, data1[index,label[i]]])
    return data3
data4=find_heuristic(start, destination)
print('Heuristics')

h=dict()
for i in data4:
    h[i[0]]=h.get(i[0],0 )+float(i[1]*10)
def H(n):
    return h[n]  
print(h)
# Out:
# Heuristics
# {'Guwahati': 8400.0, 'Rangia': 8240.0, 'Mangaldai': 7620.0, 'Udalguri': 6600.0, 'Mazbat': 5530.0, 'Rangapara': 5530.0, 'Biswanath Charali': 6050.0, 'Gohpur': 5220.0, 'Bihpuria': 6080.0, 'North Lakhimpur': 6550.0, 'Gogamukh': 4890.0, 'Dhemaji': 3940.0, 'Silapathar': 800.0, 'Jagiroad': 620.0, 'Hojai': 2340.0, 'Lamding': 2330.0, 'Diphu': 3520.0, 'Mariani': 4370.0, 'Simaluguri': 4880.0, 'Namrup': 4600.0, 'Naharkatiya': 5910.0, 'Duliajan': 5900.0, 'Bordubi': 5730.0, 'Tinsukia': 6490.0, 'Nagaon': 6460.0, 'Bokakhat': 6920.0, 'Dergaon': 7210.0, 'Jorhat': 7400.0, 'Sibsagar': 6120.0, 'Dimow': 8360.0, 'Moranhat': 7000.0, 'Dibrugarh': 0.0}

# %%
# output
begin=time.time()
solver=Graph(map)
path=solver.a_star_algorithm(start,destination)
print('Path_found:')
print(*path, sep=' --> ')
end=time.time()
print('time: ',end-begin)
# Out:
# Total node expanded: 45
# Total cost:  4074.2999999999997
# Path_found:
# Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur --> Bihpuria --> North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh
# time:  0.0007486343383789062

# %%
# randomise 50 different instances
count = 0
cities_test = copy.deepcopy(list(cities_lst))
time_lst = []  # list of running time for analysis

while count < 50:
    start_indx = randint(0, 31)
    end_indx = randint(0, 31)
    if start_indx == end_indx:
        continue
    start_test = cities_test[start_indx]
    end_test = cities_test[end_indx]
    print(f'Test {count+1}: {cities_test[start_indx]} -> {cities_test[end_indx]}')
    
    start_time = time.time()
    solver = Graph(map)
    path = solver.a_star_algorithm(start_test, end_test)
    print(*path, sep=' --> ')
    end_time = time.time()
    time_lst.append(end_time-start_time)
    print('Total execution time:', end_time-start_time)
    count += 1
# Out:
# Test 1: Dibrugarh -> Udalguri
# Total node expanded: 57
# Total cost:  3137.3
# Dibrugarh --> Silapathar --> Dhemaji --> Gogamukh --> North Lakhimpur --> Bihpuria --> Gohpur --> Biswanath Charali --> Rangapara --> Mazbat --> Udalguri
# Total execution time: 0.0004956722259521484
# Test 2: Jagiroad -> Gohpur
# Total node expanded: 29
# Total cost:  2894.0
# Jagiroad --> Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur
# Total execution time: 0.00023865699768066406
# Test 3: Nagaon -> Lamding
# Total node expanded: 19
# Total cost:  2670.5
# Nagaon --> Mangaldai --> Guwahati --> Jagiroad --> Hojai --> Lamding
# Total execution time: 0.00017309188842773438
# Test 4: North Lakhimpur -> Simaluguri
# Total node expanded: 33
# Total cost:  3679.3
# North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri
# Total execution time: 0.0004820823669433594
# Test 5: Mangaldai -> Naharkatiya
# Total node expanded: 71
# Total cost:  4211.700000000001
# Mangaldai --> Nagaon --> Bokakhat --> Dergaon --> Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya
# Total execution time: 0.0003845691680908203
# Test 6: Dimow -> Rangapara
# Total node expanded: 51
# Total cost:  3125.5999999999995
# Dimow --> Moranhat --> Dibrugarh --> Silapathar --> Dhemaji --> Gogamukh --> North Lakhimpur --> Bihpuria --> Gohpur --> Biswanath Charali --> Rangapara
# Total execution time: 0.0003376007080078125
# Test 7: Biswanath Charali -> Gohpur
# Total node expanded: 2
# Total cost:  493.7
# Biswanath Charali --> Gohpur
# Total execution time: 9.298324584960938e-05
# Test 8: Tinsukia -> Sibsagar
# Total node expanded: 47
# Total cost:  1168.6000000000001
# Tinsukia --> Dibrugarh --> Moranhat --> Dimow --> Sibsagar
# Total execution time: 0.0002281665802001953
# Test 9: Silapathar -> Jorhat
# Total node expanded: 49
# Total cost:  1448.9
# Silapathar --> Dibrugarh --> Moranhat --> Dimow --> Sibsagar --> Jorhat
# Total execution time: 0.0002827644348144531
# Test 10: Guwahati -> Diphu
# Total node expanded: 9
# Total cost:  2013.7
# Guwahati --> Jagiroad --> Hojai --> Lamding --> Diphu
# Total execution time: 0.0001552104949951172
# Test 11: Simaluguri -> Jagiroad
# Total node expanded: 10
# Total cost:  3452.4
# Simaluguri --> Mariani --> Diphu --> Lamding --> Hojai --> Jagiroad
# Total execution time: 0.0001709461212158203
# Test 12: Lamding -> Diphu
# Total node expanded: 6
# Total cost:  319.20000000000005
# Lamding --> Diphu
# Total execution time: 0.00010442733764648438
# Test 13: Gogamukh -> Dhemaji
# Total node expanded: 2
# Total cost:  250.6
# Gogamukh --> Dhemaji
# Total execution time: 0.004948616027832031
# Test 14: Bihpuria -> Diphu
# Total node expanded: 39
# Total cost:  5893.7
# Bihpuria --> North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri --> Mariani --> Diphu
# Total execution time: 0.0003859996795654297
# Test 15: Udalguri -> Nagaon
# Total node expanded: 40
# Total cost:  1913.0
# Udalguri --> Rangia --> Guwahati --> Mangaldai --> Nagaon
# Total execution time: 0.0002665519714355469
# Test 16: Jagiroad -> Bihpuria
# Total node expanded: 31
# Total cost:  3244.5
# Jagiroad --> Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur --> Bihpuria
# Total execution time: 0.0003094673156738281
# Test 17: Jagiroad -> Rangapara
# Total node expanded: 25
# Total cost:  1947.0
# Jagiroad --> Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara
# Total execution time: 0.0002033710479736328
# Test 18: North Lakhimpur -> Bordubi
# Total node expanded: 23
# Total cost:  1602.5
# North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi
# Total execution time: 0.00024437904357910156
# Test 19: Gogamukh -> Tinsukia
# Total node expanded: 19
# Total cost:  1170.1
# Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia
# Total execution time: 0.00018167495727539062
# Test 20: Nagaon -> Moranhat
# Total node expanded: 54
# Total cost:  2458.1000000000004
# Nagaon --> Bokakhat --> Dergaon --> Jorhat --> Sibsagar --> Dimow --> Moranhat
# Total execution time: 0.00035691261291503906
# Test 21: Jorhat -> Naharkatiya
# Total node expanded: 29
# Total cost:  2107.1
# Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya
# Total execution time: 0.00032067298889160156
# Test 22: Rangapara -> Bihpuria
# Total node expanded: 10
# Total cost:  1297.5
# Rangapara --> Biswanath Charali --> Gohpur --> Bihpuria
# Total execution time: 0.00015234947204589844
# Test 23: Dimow -> Dibrugarh
# Total node expanded: 6
# Total cost:  517.3
# Dimow --> Moranhat --> Dibrugarh
# Total execution time: 0.0001544952392578125
# Test 24: Hojai -> Nagaon
# Total node expanded: 19
# Total cost:  2165.1
# Hojai --> Jagiroad --> Guwahati --> Mangaldai --> Nagaon
# Total execution time: 0.00015783309936523438
# Test 25: Dimow -> Rangia
# Total node expanded: 70
# Total cost:  3591.8
# Dimow --> Sibsagar --> Jorhat --> Dergaon --> Bokakhat --> Nagaon --> Mangaldai --> Guwahati --> Rangia
# Total execution time: 0.0003192424774169922
# Test 26: Guwahati -> Bihpuria
# Total node expanded: 31
# Total cost:  2763.5
# Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur --> Bihpuria
# Total execution time: 0.0002446174621582031
# Test 27: Guwahati -> Diphu
# Total node expanded: 9
# Total cost:  2013.7
# Guwahati --> Jagiroad --> Hojai --> Lamding --> Diphu
# Total execution time: 0.0001537799835205078
# Test 28: North Lakhimpur -> Duliajan
# Total node expanded: 25
# Total cost:  1763.6
# North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan
# Total execution time: 0.00021457672119140625
# Test 29: Mariani -> Tinsukia
# Total node expanded: 20
# Total cost:  2866.3
# Mariani --> Simaluguri --> Namrup --> Naharkatiya --> Duliajan --> Bordubi --> Tinsukia
# Total execution time: 0.00021576881408691406
# Test 30: Jorhat -> Bordubi
# Total node expanded: 25
# Total cost:  1797.9
# Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Tinsukia --> Bordubi
# Total execution time: 0.0002880096435546875
# Test 31: Mazbat -> Rangia
# Total node expanded: 23
# Total cost:  762.0
# Mazbat --> Udalguri --> Rangia
# Total execution time: 0.00014662742614746094
# Test 32: Gogamukh -> Naharkatiya
# Total node expanded: 25
# Total cost:  1593.2999999999997
# Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya
# Total execution time: 0.0002281665802001953
# Test 33: Moranhat -> Jagiroad
# Total node expanded: 37
# Total cost:  6445.599999999999
# Moranhat --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri --> Mariani --> Diphu --> Lamding --> Hojai --> Jagiroad
# Total execution time: 0.00031638145446777344
# Test 34: Mariani -> Lamding
# Total node expanded: 4
# Total cost:  1563.4
# Mariani --> Diphu --> Lamding
# Total execution time: 0.00010371208190917969
# Test 35: Tinsukia -> Mariani
# Total node expanded: 21
# Total cost:  2866.3
# Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri --> Mariani
# Total execution time: 0.00013637542724609375
# Test 36: Simaluguri -> Jorhat
# Total node expanded: 49
# Total cost:  3874.7000000000007
# Simaluguri --> Namrup --> Naharkatiya --> Duliajan --> Bordubi --> Tinsukia --> Dibrugarh --> Moranhat --> Dimow --> Sibsagar --> Jorhat
# Total execution time: 0.00019288063049316406
# Test 37: Tinsukia -> Dergaon
# Total node expanded: 51
# Total cost:  1903.4
# Tinsukia --> Dibrugarh --> Moranhat --> Dimow --> Sibsagar --> Jorhat --> Dergaon
# Total execution time: 0.00014972686767578125
# Test 38: Bokakhat -> Rangapara
# Total node expanded: 55
# Total cost:  4438.499999999999
# Bokakhat --> Dergaon --> Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Silapathar --> Dhemaji --> Gogamukh --> North Lakhimpur --> Bihpuria --> Gohpur --> Biswanath Charali --> Rangapara
# Total execution time: 0.0002357959747314453
# Test 39: Udalguri -> Naharkatiya
# Total node expanded: 52
# Total cost:  4032.8999999999996
# Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur --> Bihpuria --> North Lakhimpur --> Gogamukh --> Dhemaji --> Silapathar --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya
# Total execution time: 0.00022172927856445312
# Test 40: Lamding -> Gohpur
# Total node expanded: 37
# Total cost:  4107.5
# Lamding --> Hojai --> Jagiroad --> Guwahati --> Rangia --> Udalguri --> Mazbat --> Rangapara --> Biswanath Charali --> Gohpur
# Total execution time: 0.00019693374633789062
# Test 41: Moranhat -> Silapathar
# Total node expanded: 5
# Total cost:  567.4
# Moranhat --> Dibrugarh --> Silapathar
# Total execution time: 6.4849853515625e-05
# Test 42: Dergaon -> Jagiroad
# Total node expanded: 51
# Total cost:  7546.599999999999
# Dergaon --> Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri --> Mariani --> Diphu --> Lamding --> Hojai --> Jagiroad
# Total execution time: 0.00022721290588378906
# Test 43: Jagiroad -> Dergaon
# Total node expanded: 37
# Total cost:  2814.1
# Jagiroad --> Guwahati --> Mangaldai --> Nagaon --> Bokakhat --> Dergaon
# Total execution time: 0.000133514404296875
# Test 44: Diphu -> Namrup
# Total node expanded: 12
# Total cost:  3540.8
# Diphu --> Mariani --> Simaluguri --> Namrup
# Total execution time: 0.0001888275146484375
# Test 45: Namrup -> North Lakhimpur
# Total node expanded: 33
# Total cost:  2058.2
# Namrup --> Naharkatiya --> Duliajan --> Bordubi --> Tinsukia --> Dibrugarh --> Silapathar --> Dhemaji --> Gogamukh --> North Lakhimpur
# Total execution time: 0.00015234947204589844
# Test 46: Jorhat -> Rangapara
# Total node expanded: 53
# Total cost:  3819.7999999999993
# Jorhat --> Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Silapathar --> Dhemaji --> Gogamukh --> North Lakhimpur --> Bihpuria --> Gohpur --> Biswanath Charali --> Rangapara
# Total execution time: 0.00019741058349609375
# Test 47: Bihpuria -> Gohpur
# Total node expanded: 2
# Total cost:  350.5
# Bihpuria --> Gohpur
# Total execution time: 5.1975250244140625e-05
# Test 48: Rangia -> Rangapara
# Total node expanded: 6
# Total cost:  1121.0
# Rangia --> Udalguri --> Mazbat --> Rangapara
# Total execution time: 7.200241088867188e-05
# Test 49: Rangia -> Nagaon
# Total node expanded: 29
# Total cost:  1321.0
# Rangia --> Guwahati --> Mangaldai --> Nagaon
# Total execution time: 0.0002148151397705078
# Test 50: Sibsagar -> Mariani
# Total node expanded: 39
# Total cost:  4034.8999999999996
# Sibsagar --> Dimow --> Moranhat --> Dibrugarh --> Tinsukia --> Bordubi --> Duliajan --> Naharkatiya --> Namrup --> Simaluguri --> Mariani
# Total execution time: 0.00027871131896972656
